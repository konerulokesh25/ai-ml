# %% [markdown]
# <a href="https://colab.research.google.com/github/konerulokesh25/ai-ml/blob/master/Assignment_12_(09_06_2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CSE-221710313026-k.lokesh

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
df=pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv")
df
# Out:
#      Match_SK  match_id  ... Win_Margin Country_id
# 0           0    335987  ...      140.0          1
# 1           1    335988  ...       33.0          1
# 2           2    335989  ...        9.0          1
# 3           3    335990  ...        5.0          1
# 4           4    335991  ...        5.0          1
# ..        ...       ...  ...        ...        ...
# 632       632   1082646  ...       10.0          1
# 633       633   1082647  ...       20.0          1
# 634       634   1082648  ...        7.0          1
# 635       635   1082649  ...        6.0          1
# 636       636   1082650  ...        1.0          1
#
# [637 rows x 17 columns]

# %%
#2.
a=df['Country_Name'].unique()
b=a
count=df['Country_Name'].value_counts()
lab=[count[0],count[1],count[2]]
plt.pie(lab,labels=b,autopct="%0.1f%%",radius=1.5,colors=["purple","violet","lavender"])
plt.plot()
# Out:
# []

# %%
#2.

# %%
df2=df[df["City_Name"]=="Hyderabad"]
data1 = df2["ManOfMach"].value_counts().rename_axis('players').reset_index(name='no.of ManOfMach')
data2 = data1.sort_values(by=['players'],ascending=True,ignore_index=True)
data2.head(29)
# Out:
#               players  no.of ManOfMach
# 0            A Mishra                2
# 1            AB Dinda                1
# 2           AT Rayudu                1
# 3             B Kumar                1
# 4           CH Morris                1
# 5           DA Warner                6
# 6            DJ Bravo                1
# 7           DJG Sammy                1
# 8            DW Steyn                3
# 9           G Gambhir                1
# 10          GH Vihari                2
# 11           I Sharma                1
# 12     MJ McClenaghan                1
# 13           MR Marsh                1
# 14      Mandeep Singh                1
# 15  Mustafizur Rahman                1
# 16           PA Patel                1
# 17        PC Valthaty                1
# 18      R Vinay Kumar                1
# 19         SC Ganguly                1
# 20           SE Marsh                1
# 21           SK Raina                2
# 22         SK Trivedi                1
# 23         SL Malinga                1
# 24           UT Yadav                1
# 25            V Kohli                1
# 26           V Sehwag                2
# 27            WP Saha                1
# 28          YK Pathan                2
